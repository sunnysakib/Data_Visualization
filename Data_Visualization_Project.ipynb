# %% [markdown]
# <a href="https://colab.research.google.com/github/sunnysakib/Data_Visualization/blob/main/Data_Visualization_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('ReelView.csv')
df_index = pd.read_csv('ReelView.csv', index_col="genre")

# %%
df.shape
# Out:
# (3990, 8)

# %%
df.describe

# %%
df.duplicated().sum()
# Out:
# 25

# %%
df.isnull().sum()
# Out:
# title             0
# stars_rating      0
# run_time          3
# release_date    284
# mpaa_rating     320
# genre             0
# director          1
# cast             13
# dtype: int64

# %%
df.head(2000)
# Out:
#                                            title  stars_rating  run_time  \
# 0                            Terms of Endearment           2.5     132.0
# 1                                           1917           3.5     110.0
# 2                              Spies in Disguise           2.0     101.0
# 3                                     Just Mercy           3.0     136.0
# 4                                   Little Women           3.0     135.0
# ...                                          ...           ...       ...
# 1995                              Into the Woods           2.5     125.0
# 1996                                       Annie           2.0     118.0
# 1997                         Imitation Game, The           3.5     114.0
# 1998                               Inherent Vice           3.0     148.0
# 1999  Hobbit, The: The Battle of the Five Armies           3.5     144.0
#
#       release_date                                        mpaa_rating  \
# 0           1983.0                          Profanity, Sexual Content
# 1           2019.0                        Violence, Disturbing Images
# 2           2019.0                                                NaN
# 3           2019.0                            Profanity, Adult Themes
# 4           2019.0                                                NaN
# ...            ...                                                ...
# 1995        2014.0                                                NaN
# 1996        2014.0                                                NaN
# 1997        2014.0                          Profanity, Sexual Content
# 1998        2014.0  Profanity, Violence, Drugs, Sexual Content, Nu...
# 1999        2014.0                                           Violence
#
#                   genre                director  \
# 0          Drama/Comedy         James L. Brooks
# 1                   War              Sam Mendes
# 2              Animated  Nick Bruno, Troy Quane
# 3                 Drama   Destin Daniel Cretton
# 4                 Drama            Greta Gerwig
# ...                 ...                     ...
# 1995            MUSICAL            Rob Marshall
# 1996            MUSICAL              Will Gluck
# 1997              DRAMA           Morten Tyldum
# 1998    THRILLER/COMEDY    Paul Thomas Anderson
# 1999  FANTASY/ADVENTURE           Peter Jackson
#
#                                                    cast
# 0     Shirley MacLaine, Debra Winger, Jack Nicholson...
# 1                   George MacKay, Dean-Charles Chapman
# 2     Will Smith, Tom Holland, Rashida Jones, Ben Me...
# 3     Michael B. Jordan, Jamie Foxx, Brie Larson, Ti...
# 4     Saoirse Ronan, Chris Cooper, Louis Garrel, Jam...
# ...                                                 ...
# 1995  Johnny Depp, Meryl Streep, Emily Blunt, Anna K...
# 1996  Jamie Foxx, Quvenzhane Wallis, Rose Byrne, Bob...
# 1997  Mark Strong, Charles Dance, Keira Knightley, M...
# 1998  Reese Witherspoon, Owen Wilson, Jena Malone, E...
# 1999  Cate Blanchett, Richard Armitage, Luke Evans, ...
#
# [2000 rows x 8 columns]

# %%
sns.histplot(df['run_time'], bins=100, kde=True).set_xlim(50, 300)
plt.title("Fig2: Count Maximum Run Time")
# Out:
# Text(0.5, 1.0, 'Fig2: Count Maximum Run Time')

# %%
sns.histplot(df['release_date'], kde=True)
plt.title("Fig3: Count Maximum movie release date")
# Out:
# Text(0.5, 1.0, 'Fig3: Count Maximum movie release date')

# %%
sns.countplot(x='stars_rating',data=df)
plt.title('Value Counts of Rating Stars')
# Out:
# Text(0.5, 1.0, 'Value Counts of Rating Stars')

# %%
df.head()

# %%
bars = df['mpaa_rating'].value_counts()
bars

# %%
bars1 = bars[['Violence, Profanity', 'Violence', 'Profanity',
       'Profanity, Sexual Content', 'Nothing Objectionable'
       ]]

bars1
# Out:
# Violence, Profanity          445
# Violence                     291
# Profanity                    185
# Profanity, Sexual Content    156
# Nothing Objectionable         99
# Name: mpaa_rating, dtype: int64

# %%
plt.bar(bars1.index, bars1.values, color='g')
plt.xticks(rotation = 10)
plt.rcParams['font.size'] = 8
plt.title('fig4: mpaa rating')
# Out:
# Text(0.5, 1.0, 'fig4: mpaa rating')

# %%
sns.histplot(df['stars_rating'], bins=5)
# Out:
# <Axes: xlabel='stars_rating', ylabel='Count'>

# %%
sns.boxplot(data=df, x='stars_rating', y='release_date')
plt.title('fig5: stars_rating by release_date')
# Out:
# Text(0.5, 1.0, 'fig5: stars_rating by release_date')

# %%
df.genre.nunique()
# Out:
# 226

# %%
df.genre.value_counts(normalize=True)*100
# Out:
# DRAMA                        17.669173
# COMEDY                        7.844612
# THRILLER                      6.967419
# Drama                         6.591479
# Thriller                      3.007519
#                                ...
# WESTERN/ADVENTURE             0.025063
# SCIENCE FICTION/WESTERN       0.025063
# Adventure/Fantasy/Musical     0.025063
# Adventure/Thriller            0.025063
# Fantasy/Action                0.025063
# Name: genre, Length: 226, dtype: float64

# %%
df[['genre']].value_counts()
# Out:
# genre
# DRAMA               705
# COMEDY              313
# THRILLER            278
# Drama               263
# Thriller            120
#                    ...
# FANTASY/MUSICAL       1
# FAMILY/ADVENTURE      1
# FAMILY DRAMA          1
# FAMILY COMEDY         1
# Western/Drama         1
# Length: 226, dtype: int64

# %%
df_genre = df_index.loc[['DRAMA', 'THRILLER', 'COMEDY', 'Fantasy/Action', 'War']]
df_genre

# %%
sns.heatmap(df.corr(),linewidths=1,linecolor='white')
plt.title('fig8: correlation matrix')
# Out:
# <ipython-input-3-9580fcecfbb7>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),linewidths=1,linecolor='white')
# Text(0.5, 1.0, 'fig8: correlation matrix')

# %%
df.head()
# Out:
#                  title  stars_rating  run_time  release_date  \
# 0  Terms of Endearment           2.5     132.0        1983.0
# 1                 1917           3.5     110.0        2019.0
# 2    Spies in Disguise           2.0     101.0        2019.0
# 3           Just Mercy           3.0     136.0        2019.0
# 4         Little Women           3.0     135.0        2019.0
#
#                    mpaa_rating         genre                director  \
# 0    Profanity, Sexual Content  Drama/Comedy         James L. Brooks
# 1  Violence, Disturbing Images           War              Sam Mendes
# 2                          NaN      Animated  Nick Bruno, Troy Quane
# 3      Profanity, Adult Themes         Drama   Destin Daniel Cretton
# 4                          NaN         Drama            Greta Gerwig
#
#                                                 cast
# 0  Shirley MacLaine, Debra Winger, Jack Nicholson...
# 1                George MacKay, Dean-Charles Chapman
# 2  Will Smith, Tom Holland, Rashida Jones, Ben Me...
# 3  Michael B. Jordan, Jamie Foxx, Brie Larson, Ti...
# 4  Saoirse Ronan, Chris Cooper, Louis Garrel, Jam...

# %%
df_value = df['director'].value_counts()[0:10]
df_value
# Out:
# Steven Soderbergh    24
# Steven Spielberg     24
# Ridley Scott         21
# Woody Allen          20
# Clint Eastwood       20
# Kenneth Branagh      15
# Michael Bay          14
# Ron Howard           14
# Guy Ritchie          14
# Martin Scorsese      13
# Name: director, dtype: int64

# %%
plt.bar(df_value.index, df_value.values)
plt.xticks(rotation = 20)
plt.rcParams['font.size'] = 8
plt.suptitle('fig6: Top 10 Director')
# Out:
# Text(0.5, 0.98, 'fig6: Top 10 Director')

# %%
runtime = df["run_time"]
runtime_cat = []
for i in runtime:
    if i < 60:
        runtime_cat.append("Under_1_hour")
    elif i < 90:
        runtime_cat.append("Under_1.5_hours")
    elif i < 120:
        runtime_cat.append("Under_2_hours")
    elif i >= 120:
        runtime_cat.append("Over_2_hours")
    else:
        runtime_cat.append(i)

plt.pie([runtime_cat.count("Under_1_hour"),
         runtime_cat.count("Under_1.5_hours"),
         runtime_cat.count("Under_2_hours"),
         runtime_cat.count("Over_2_hours")],
       labels = ["Under_1_hour", "Under_1.5_hours", "Under_2_hours", "Over_2_hours"])
plt.title("fig 7. Distribution of movie runtime over different movies")
# Out:
# Text(0.5, 1.0, 'fig 7. Distribution of movie runtime over different movies')
